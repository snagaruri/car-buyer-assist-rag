# %%
import pandas as pd

# %%
pd.read_json("row_format.jsonl", lines=True)
# Out:
#             model   type  price
# 0  Toyota Corolla  Sedan  22000
# 1     Toyota RAV4    SUV  30000
# 2    Toyota Camry  Sedan  28000

# %%
df = pd.read_json("row_format.jsonl", lines=True)

# %%
type(df)
# Out:
# pandas.DataFrame

# %%
df.columns
# Out:
# Index(['model', 'type', 'price'], dtype='str')

# %%
df[["model", "price"]]
# Out:
#             model  price
# 0  Toyota Corolla  22000
# 1     Toyota RAV4  30000
# 2    Toyota Camry  28000

# %%
pd.read_json("column_format.json")
# Out:
#      model   type  price
# 0  Corolla  Sedan  22000
# 1     RAV4    SUV  28000
# 2    Camry  Sedan  26000

# %%
df
# Out:
#             model   type  price
# 0  Toyota Corolla  Sedan  22000
# 1     Toyota RAV4    SUV  30000
# 2    Toyota Camry  Sedan  28000

# %%
df.to_dict()
# Out:
# {'model': {0: 'Toyota Corolla', 1: 'Toyota RAV4', 2: 'Toyota Camry'},
#  'type': {0: 'Sedan', 1: 'SUV', 2: 'Sedan'},
#  'price': {0: 22000, 1: 30000, 2: 28000}}

# %%
df.to_dict(orient="records")
# Out:
# [{'model': 'Toyota Corolla', 'type': 'Sedan', 'price': 22000},
#  {'model': 'Toyota RAV4', 'type': 'SUV', 'price': 30000},
#  {'model': 'Toyota Camry', 'type': 'Sedan', 'price': 28000}]
