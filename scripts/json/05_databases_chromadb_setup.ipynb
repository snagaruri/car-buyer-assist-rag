# %%
import chromadb

# %%
print(f"ChromaDB version: {chromadb.__version__}")
print("Installation successful")
# Out:
# ChromaDB version: 1.5.0
# Installation successful

# %%
client = chromadb.Client()

# %%
collection = client.create_collection("test_cars")

# %%
# Add test document
collection.add(
    documents=["Toyota Corolla: Affordable reliable sedan"],
    ids=["corolla_test"],
    metadatas=[{"model": "Corolla", "price": 22000}]
)

# %%
print(f"Documents: {collection.count()}")
# Out:
# Documents: 1

# %%
# Query test
results = collection.query(
    query_texts=["economical car"],
    n_results=1
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Query test
# ----> 2 results = collection.query(
#       3     query_texts=["economical car"],
#       4     n_results=1
#       5 )
#
# File ~/Desktop/Learning/AI_ITversity/Projects/CAR-BUYER-ASSIST-RAG/cbar-venv/lib/python3.11/site-packages/chromadb/api/models/Collection.py:253, in Collection.query(self, query_embeddings, query_texts, query_images, query_uris, ids, n_results, where, where_document, include)
#     203 """Query for the K nearest neighbor records in the collection.
#     204
#     205 This is a batch query API. Multiple queries can be performed at once
#    (...)    238     ValueError: If multiple query input types are provided.
#     239 """
#     241 query_request = self._validate_and_prepare_query_request(
#     242     query_embeddings=query_embeddings,
# ...

# %%
print("Query: 'economical car'")
print(f"Found: {results['metadatas'][0][0]['model']}")
print("ChromaDB working!")
# Out:
# Query: 'economical car'
# Found: Corolla
# ChromaDB working!

# %%
results
# Out:
# {'ids': [['corolla_test']],
#  'embeddings': None,
#  'documents': [['Toyota Corolla: Affordable reliable sedan']],
#  'uris': None,
#  'included': ['metadatas', 'documents', 'distances'],
#  'data': None,
#  'metadatas': [[{'model': 'Corolla', 'price': 22000}]],
#  'distances': [[0.8715280890464783]]}

# %%
results['metadatas'][0][0]['model']
# Out:
# 'Corolla'

# %%
# Clean up
client.delete_collection(name="test_cars")
print("Test complete")
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Clean up
# ----> 2 client.delete_collection(name="test_cars")
#       3 print("Test complete")
#
# File ~/Desktop/Learning/AI_ITversity/Projects/CAR-BUYER-ASSIST-RAG/cbar-venv/lib/python3.11/site-packages/chromadb/api/client.py:353, in Client.delete_collection(self, name)
#     348 @override
#     349 def delete_collection(
#     350     self,
#     351     name: str,
#     352 ) -> None:
# --> 353     return self._server.delete_collection(
#     354         name=name,
#     355         tenant=self.tenant,
#     356         database=self.database,
#     357     )
#
# File ~/Desktop/Learning/AI_ITversity/Projects/CAR-BUYER-ASSIST-RAG/cbar-venv/lib/python3.11/site-packages/chromadb/api/rust.py:304, in RustBindingsAPI.delete_collection(self, name, tenant, database)
#     297 @override
# ...
